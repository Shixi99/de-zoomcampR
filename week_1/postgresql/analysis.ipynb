# %%
import pandas as pd

# %%
df = pd.read_csv('data/green_tripdata_2019-01.csv.gz', compression='gzip')

# %%
df.shape
# Out:
# (630918, 20)

# %%
df.head()
# Out:
#    VendorID lpep_pickup_datetime lpep_dropoff_datetime store_and_fwd_flag  \
# 0         2  2018-12-21 15:17:29   2018-12-21 15:18:57                  N
# 1         2  2019-01-01 00:10:16   2019-01-01 00:16:32                  N
# 2         2  2019-01-01 00:27:11   2019-01-01 00:31:38                  N
# 3         2  2019-01-01 00:46:20   2019-01-01 01:04:54                  N
# 4         2  2019-01-01 00:19:06   2019-01-01 00:39:43                  N
#
#    RatecodeID  PULocationID  DOLocationID  passenger_count  trip_distance  \
# 0           1           264           264                5           0.00
# 1           1            97            49                2           0.86
# 2           1            49           189                2           0.66
# 3           1           189            17                2           2.68
# 4           1            82           258                1           4.53
#
#    fare_amount  extra  mta_tax  tip_amount  tolls_amount  ehail_fee  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 630918 entries, 0 to 630917
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   VendorID               630918 non-null  int64
#  1   lpep_pickup_datetime   630918 non-null  object
#  2   lpep_dropoff_datetime  630918 non-null  object
#  3   store_and_fwd_flag     630918 non-null  object
#  4   RatecodeID             630918 non-null  int64
#  5   PULocationID           630918 non-null  int64
#  6   DOLocationID           630918 non-null  int64
#  7   passenger_count        630918 non-null  int64
#  8   trip_distance          630918 non-null  float64
#  9   fare_amount            630918 non-null  float64
#  10  extra                  630918 non-null  float64
#  11  mta_tax                630918 non-null  float64
#  12  tip_amount             630918 non-null  float64
#  13  tolls_amount           630918 non-null  float64
# ...

# %%
# tpep_pickup_datetime	tpep_dropoff_datetime	
df['lpep_pickup_datetime'] = pd.to_datetime(df['lpep_pickup_datetime'])
df['lpep_dropoff_datetime'] = pd.to_datetime(df['lpep_dropoff_datetime'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 630918 entries, 0 to 630917
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   VendorID               630918 non-null  int64
#  1   lpep_pickup_datetime   630918 non-null  datetime64[ns]
#  2   lpep_dropoff_datetime  630918 non-null  datetime64[ns]
#  3   store_and_fwd_flag     630918 non-null  object
#  4   RatecodeID             630918 non-null  int64
#  5   PULocationID           630918 non-null  int64
#  6   DOLocationID           630918 non-null  int64
#  7   passenger_count        630918 non-null  int64
#  8   trip_distance          630918 non-null  float64
#  9   fare_amount            630918 non-null  float64
#  10  extra                  630918 non-null  float64
#  11  mta_tax                630918 non-null  float64
#  12  tip_amount             630918 non-null  float64
#  13  tolls_amount           630918 non-null  float64
# ...

# %% [markdown]
# ### Question 3

# %%
filt = ((df['lpep_pickup_datetime'].dt.day == 15) 
& (df['lpep_dropoff_datetime'].dt.day == 15) 
& (df['lpep_dropoff_datetime'].dt.year == 2019) 
& (df['lpep_dropoff_datetime'].dt.month == 1))
df[filt].count()
# Out:
# VendorID                 20530
# lpep_pickup_datetime     20530
# lpep_dropoff_datetime    20530
# store_and_fwd_flag       20530
# RatecodeID               20530
# PULocationID             20530
# DOLocationID             20530
# passenger_count          20530
# trip_distance            20530
# fare_amount              20530
# extra                    20530
# mta_tax                  20530
# tip_amount               20530
# tolls_amount             20530
# ehail_fee                    0
# improvement_surcharge    20530
# total_amount             20530
# payment_type             20530
# trip_type                20530
# congestion_surcharge         0
# dtype: int64

# %% [markdown]
# ### Question 4

# %%
# df.sort_values(by='trip_distance', ascending=False
df[df['trip_distance'] == (df['trip_distance'].max())]
# Out:
#         VendorID lpep_pickup_datetime lpep_dropoff_datetime  \
# 297377         2  2019-01-15 19:27:58   2019-01-15 22:59:01
#
#        store_and_fwd_flag  RatecodeID  PULocationID  DOLocationID  \
# 297377                  N           1           221           265
#
#         passenger_count  trip_distance  fare_amount  extra  mta_tax  \
# 297377                1         117.99        323.0    1.0      0.5
#
#         tip_amount  tolls_amount  ehail_fee  improvement_surcharge  \
# 297377         0.0          10.5        NaN                    0.3
#
#         total_amount  payment_type  trip_type  congestion_surcharge
# 297377         339.2             2          1                   NaN

# %% [markdown]
# ### Question 5

# %%
filt = ((df['lpep_pickup_datetime'].dt.day == 1) 
& (df['lpep_dropoff_datetime'].dt.day == 1) 
& (df['lpep_dropoff_datetime'].dt.year == 2019) 
& (df['lpep_dropoff_datetime'].dt.month == 1))
df[filt]['passenger_count'].value_counts()#.groupby(df['passenger_count']).count()
# Out:
# 1    12298
# 2     1266
# 5      609
# 6      273
# 3      253
# 4      129
# 0       21
# Name: passenger_count, dtype: int64

# %%
df[filt].groupby('passenger_count').count()
# Out:
#                  VendorID  lpep_pickup_datetime  lpep_dropoff_datetime  \
# passenger_count
# 0                      21                    21                     21
# 1                   12298                 12298                  12298
# 2                    1266                  1266                   1266
# 3                     253                   253                    253
# 4                     129                   129                    129
# 5                     609                   609                    609
# 6                     273                   273                    273
#
#                  store_and_fwd_flag  RatecodeID  PULocationID  DOLocationID  \
# passenger_count
# 0                                21          21            21            21
# 1                             12298       12298         12298         12298
# 2                              1266        1266          1266          1266
# ...

# %%
df[(df['lpep_pickup_datetime'] >= '2019-01-01 00:00:00') 
& ( df['lpep_dropoff_datetime'] <= '2019-01-01 23:59:59')].groupby(df['passenger_count']).count()
# Out:
#                  VendorID  lpep_pickup_datetime  lpep_dropoff_datetime  \
# passenger_count
# 0                      21                    21                     21
# 1                   12298                 12298                  12298
# 2                    1266                  1266                   1266
# 3                     253                   253                    253
# 4                     129                   129                    129
# 5                     609                   609                    609
# 6                     273                   273                    273
#
#                  store_and_fwd_flag  RatecodeID  PULocationID  DOLocationID  \
# passenger_count
# 0                                21          21            21            21
# 1                             12298       12298         12298         12298
# 2                              1266        1266          1266          1266
# ...

# %% [markdown]
# ### Question 6

# %%
zone_df = pd.read_csv('taxi+_zone_lookup.csv')

# %%
df_zone_and_location_pu = pd.merge(df, zone_df, left_on='PULocationID', right_on='LocationID', how='inner')

# %%
df_zone_and_location_pu_do = pd.merge(df_zone_and_location_pu, zone_df, left_on='DOLocationID', right_on='LocationID', how='inner')

# %%
df_zone_and_location_pu_do = \
df_zone_and_location_pu_do.rename(
    columns={
        'Zone_x':'Zone_PU',
        'Zone_y':'Zone_DO'
    }
)

# %%
df_final = df_zone_and_location_pu_do[['VendorID','lpep_pickup_datetime','lpep_dropoff_datetime','PULocationID','DOLocationID','tip_amount','Zone_PU', 'Zone_DO']]

# %%
df_final
# Out:
#         VendorID lpep_pickup_datetime lpep_dropoff_datetime  PULocationID  \
# 0              2  2018-12-21 15:17:29   2018-12-21 15:18:57           264
# 1              2  2019-01-01 00:36:29   2019-01-01 00:36:29           264
# 2              2  2019-01-01 00:22:43   2019-01-01 00:54:37           264
# 3              2  2019-01-01 04:43:26   2019-01-01 04:43:26           264
# 4              2  2019-01-01 05:46:04   2019-01-01 05:46:04           264
# ...          ...                  ...                   ...           ...
# 630913         2  2019-01-20 16:47:13   2019-01-20 16:58:48           118
# 630914         2  2019-01-15 14:42:49   2019-01-15 14:59:00            23
# 630915         2  2019-01-07 09:19:45   2019-01-07 09:59:28            26
# 630916         2  2019-01-21 09:17:53   2019-01-21 09:52:20            26
# 630917         2  2019-01-16 14:47:02   2019-01-16 15:00:39            54
#
#         DOLocationID  tip_amount                      Zone_PU  \
# ...

# %%
df_final[(df_final['Zone_PU']=='Astoria')].sort_values('tip_amount', ascending=False)
# Out:
#         VendorID lpep_pickup_datetime lpep_dropoff_datetime  PULocationID  \
# 203965         2  2019-01-26 00:46:06   2019-01-26 00:50:10             7
# 550090         2  2019-01-24 12:58:02   2019-01-24 13:29:59             7
# 175402         2  2019-01-20 22:48:21   2019-01-20 23:18:05             7
# 500721         1  2019-01-17 08:21:52   2019-01-17 08:56:59             7
# 500714         2  2019-01-02 04:17:39   2019-01-02 05:09:07             7
# ...          ...                  ...                   ...           ...
# 165729         2  2019-01-13 04:03:50   2019-01-13 04:03:53             7
# 165728         2  2019-01-13 04:13:32   2019-01-13 04:15:18             7
# 165727         2  2019-01-13 03:48:41   2019-01-13 03:52:03             7
# 630670         2  2019-01-19 12:04:02   2019-01-19 12:52:21             7
# 68677          2  2019-01-20 12:21:37   2019-01-20 12:22:02             7
#
#         DOLocationID  tip_amount  Zone_PU                        Zone_DO
# ...

# %% [markdown]
# ### Loading data to postgresql

# %%
print(pd.io.sql.get_schema(df, name='green_taxi_data'))
# Out:
# CREATE TABLE "green_taxi_data" (
# "VendorID" INTEGER,
#   "lpep_pickup_datetime" TIMESTAMP,
#   "lpep_dropoff_datetime" TIMESTAMP,
#   "store_and_fwd_flag" TEXT,
#   "RatecodeID" INTEGER,
#   "PULocationID" INTEGER,
#   "DOLocationID" INTEGER,
#   "passenger_count" INTEGER,
#   "trip_distance" REAL,
#   "fare_amount" REAL,
#   "extra" REAL,
#   "mta_tax" REAL,
#   "tip_amount" REAL,
#   "tolls_amount" REAL,
#   "ehail_fee" REAL,
#   "improvement_surcharge" REAL,
#   "total_amount" REAL,
#   "payment_type" INTEGER,
#   "trip_type" INTEGER,
#   "congestion_surcharge" REAL
# )

# %%
# from sqlalchemy import create_engine
# import pandas as pd

# engine = create_engine('postgresql://root:root@localhost/ny_taxi')
# engine.connect()

# %%
from sqlalchemy import create_engine
import pandas as pd

engine = create_engine('postgresql://postgres:2130020@localhost/postgres')
engine.connect()

# %%
pd.read_sql('select 2 as two', con=engine)
# Out:
#    two
# 0    2

# %%
print(pd.io.sql.get_schema(df, 'green_taxi_data', con=engine))
# Out:
# CREATE TABLE green_taxi_data (
# 	"VendorID" BIGINT,
# 	lpep_pickup_datetime TEXT,
# 	lpep_dropoff_datetime TEXT,
# 	store_and_fwd_flag TEXT,
# 	"RatecodeID" BIGINT,
# 	"PULocationID" BIGINT,
# 	"DOLocationID" BIGINT,
# 	passenger_count BIGINT,
# 	trip_distance FLOAT(53),
# 	fare_amount FLOAT(53),
# 	extra FLOAT(53),
# 	mta_tax FLOAT(53),
# 	tip_amount FLOAT(53),
# 	tolls_amount FLOAT(53),
# 	ehail_fee FLOAT(53),
# 	improvement_surcharge FLOAT(53),
# 	total_amount FLOAT(53),
# 	payment_type BIGINT,
# 	trip_type BIGINT,
# 	congestion_surcharge FLOAT(53)
# )

# %%
df_iter = pd.read_csv('green_tripdata_2019-01.csv.gz', iterator=True, chunksize=100000)

# %%
df_iter

# %%
df = next(df_iter)

# %%
len(df)
# Out:
# 100000

# %%
df['lpep_pickup_datetime'] = pd.to_datetime(df['lpep_pickup_datetime'])
df['lpep_dropoff_datetime'] = pd.to_datetime(df['lpep_dropoff_datetime'])

# %%
df.head(0)
# Out:
# Empty DataFrame
# Columns: [VendorID, lpep_pickup_datetime, lpep_dropoff_datetime, store_and_fwd_flag, RatecodeID, PULocationID, DOLocationID, passenger_count, trip_distance, fare_amount, extra, mta_tax, tip_amount, tolls_amount, ehail_fee, improvement_surcharge, total_amount, payment_type, trip_type, congestion_surcharge]
# Index: []

# %%
df.head(0).to_sql(name='green_taxi_data', con=engine, if_exists='replace')
# Out:
# 0

# %%
pd.read_sql('select * from green_taxi_data', con=engine)
# Out:
# Empty DataFrame
# Columns: [index, VendorID, lpep_pickup_datetime, lpep_dropoff_datetime, store_and_fwd_flag, RatecodeID, PULocationID, DOLocationID, passenger_count, trip_distance, fare_amount, extra, mta_tax, tip_amount, tolls_amount, ehail_fee, improvement_surcharge, total_amount, payment_type, trip_type, congestion_surcharge]
# Index: []
#
# [0 rows x 21 columns]

# %%
df = df.head(10)
# %time df.to_sql(name='green_taxi_data', con=engine, if_exists='replace')
# Out:
# CPU times: user 24.3 ms, sys: 5.56 ms, total: 29.9 ms
# Wall time: 122 ms
# 10

# %%
pd.read_sql('select count(*) from green_taxi_data', con=engine)
# Out:
#    count
# 0     10

# %%
# pd.read_sql('truncate table green_taxi_data', con=engine)

# %%
# from time import time

# while True:
#     start = time()
#     df = next(df_iter)
#     df.to_sql(name='green_taxi_data', con=engine, if_exists='append')
#     end = time()
#     print(f'inserted another chunck..., took {round((end-start),3)} seconds')

# %%
df = pd.read_csv('data/green_tripdata_2019-01.csv.gz')

df['lpep_pickup_datetime'] = pd.to_datetime(df['lpep_pickup_datetime'])
df['lpep_dropoff_datetime'] = pd.to_datetime(df['lpep_dropoff_datetime'])

# %time df.to_sql(name='green_taxi_data', con=engine, if_exists='replace')
# Out:
# CPU times: user 33.9 s, sys: 699 ms, total: 34.6 s
# Wall time: 1min 16s
# 918

# %%
# !python --version
# Out:
# Python 3.9.6

# %%
import csv
from io import StringIO
import time

import pandas as pd
from sqlalchemy import create_engine

# %%
import csv, time
from io import StringIO


# Custom insert method for DataFrame.to_sql
def psql_insert_copy(table, conn, keys, data_iter):
    """
    Execute SQL statement inserting data

    Parameters
    ----------
    table : pandas.io.sql.SQLTable
    conn : sqlalchemy.engine.Engine or sqlalchemy.engine.Connection
    keys : list of str
        Column names
    data_iter : Iterable that iterates the values to be inserted
    """
    # gets a DBAPI connection that can provide a cursor
    dbapi_conn = conn.connection
    with dbapi_conn.cursor() as cur:
        s_buf = StringIO()
        writer = csv.writer(s_buf)
        writer.writerows(data_iter)
        s_buf.seek(0)

        columns = ', '.join(f'"{k}"' for k in keys)
        table_name = f'"{table.schema}"."{table.name}"'
        sql = f'COPY {table_name} ({columns}) FROM STDIN WITH CSV'
        cur.copy_expert(sql=sql, file=s_buf)

# %%
df = pd.read_csv('data/green_tripdata_2019-01.csv.gz', compression='gzip')

engine = create_engine('postgresql://postgres:2130020@localhost:5433/postgres')
# engine.connect()

start_time = time.time()
with engine.begin() as conn:
  df.to_sql(
    "green_taxi_data",
    conn,
    schema="public",
    index=False,
    method=psql_insert_copy,
    if_exists="replace")
print(f'Fast custom insert required {time.time() - start_time:.1f} seconds.')
# Out:
# Fast custom insert required 6.9 seconds.

# %%
schema = 'pg_catalog'
tables=pd.read_sql(f'select * from information_schema.tables', con=engine)

# %%
tables[tables.table_schema=='public']
# Out:
#   table_catalog table_schema        table_name  table_type  \
# 0      postgres       public   green_taxi_data  BASE TABLE
# 3      postgres       public  green_taxi_data2  BASE TABLE
#
#   self_referencing_column_name reference_generation user_defined_type_catalog  \
# 0                         None                 None                      None
# 3                         None                 None                      None
#
#   user_defined_type_schema user_defined_type_name is_insertable_into is_typed  \
# 0                     None                   None                YES       NO
# 3                     None                   None                YES       NO
#
#   commit_action
# 0          None
# 3          None

# %%
pd.read_sql(f'select * from green_taxi_data2', con=engine)
# Out:
#     index  VendorID lpep_pickup_datetime lpep_dropoff_datetime  \
# 0       0         2  2018-12-21 15:17:29   2018-12-21 15:18:57
# 1       1         2  2019-01-01 00:10:16   2019-01-01 00:16:32
# 2       2         2  2019-01-01 00:27:11   2019-01-01 00:31:38
# 3       3         2  2019-01-01 00:46:20   2019-01-01 01:04:54
# 4       4         2  2019-01-01 00:19:06   2019-01-01 00:39:43
# ..    ...       ...                  ...                   ...
# 95     95         2  2019-01-01 00:15:42   2019-01-01 00:41:04
# 96     96         2  2019-01-01 00:21:28   2019-01-01 00:48:15
# 97     97         2  2019-01-01 00:17:10   2019-01-01 00:23:34
# 98     98         2  2019-01-01 00:25:01   2019-01-01 00:43:55
# 99     99         2  2019-01-01 00:36:56   2019-01-01 00:43:50
#
#    store_and_fwd_flag  RatecodeID  PULocationID  DOLocationID  \
# 0                   N           1           264           264
# 1                   N           1            97            49
# ...
